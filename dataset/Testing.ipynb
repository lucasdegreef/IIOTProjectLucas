# %%
import pandas as pd

dataset = pd.read_csv("manufacturing_dataset.csv",sep=";")

dataset.head()
# Out:
#   Production ID        Date Product Type  Machine ID        Shift  \
# 0    1899-12-31  2020-01-01   Automotive           3  Eearly_Late
# 1    1900-01-01  2020-01-02     Textiles           8        Night
# 2    1900-01-02  2020-01-03   Appliances          11  Eearly_Late
# 3    1900-01-03  2020-01-04   Appliances          11          Day
# 4    1900-01-04  2020-01-05  Electronics          14        Night
#
#    Units Produced  Defects  Production Time Hours  Material Cost Per Unit  \
# 0             142      3.0                  23.42                   38.68
# 1             170      4.0                   7.51                   21.35
# 2             182      4.0                  20.58                   47.54
# 3             133      NaN                  21.68                   40.21
# 4              82      NaN                  16.68                   38.02
#
#    Labour Cost Per Hour  Energy Consumption kWh  Operator Count  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Production ID                   3000 non-null   str
#  1   Date                            3000 non-null   str
#  2   Product Type                    3000 non-null   str
#  3   Machine ID                      3000 non-null   int64
#  4   Shift                           3000 non-null   str
#  5   Units Produced                  3000 non-null   int64
#  6   Defects                         2701 non-null   float64
#  7   Production Time Hours           3000 non-null   float64
#  8   Material Cost Per Unit          3000 non-null   float64
#  9   Labour Cost Per Hour            3000 non-null   float64
#  10  Energy Consumption kWh          3000 non-null   float64
#  11  Operator Count                  3000 non-null   int64
# ...

# %%
dataset.loc[dataset["Down time Hours"].isna()]
# Out:
#      Production ID        Date Product Type  Machine ID        Shift  \
# 5       1900-01-05  2020-01-06   Automotive           1        Night
# 14      1900-01-14  2020-01-15    Furniture          17        Night
# 15      1900-01-15  2020-01-16   Automotive           3        Night
# 28      1900-01-28  2020-01-29   Appliances          12  Eearly_Late
# 43      1900-02-12  2020-02-13    Furniture          19  Eearly_Late
# ...            ...         ...          ...         ...          ...
# 2877    1907-11-17  2027-11-17   Automotive           2        Night
# 2902    1907-12-12  2027-12-12     Textiles           6          Day
# 2965    1908-02-13  2028-02-13   Automotive           3          Day
# 2982    1908-03-01  2028-03-01  Electronics          16          Day
# 2999          3000  2028-03-18   Appliances          12        Night
#
#       Units Produced  Defects  Production Time Hours  Material Cost Per Unit  \
# ...
